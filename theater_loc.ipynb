# %% [markdown]
# # New theater location selection in NYC
# ## INTRODUCTION
# ### This project would like to investigate the potential location of an invested theater location in NYC. In order to obtain the potential places, the clustering technique will be applied to rank venues especially to discover where the theaters have been located. Finally choosing the ranking no. 1 venues as the aiming location.
# ## Data
# ### The Foursquare location data will be applied to complete the "New theater location selection in NYC" project. The Manhattan county will be the target town and be explored from the Foursquare developer website. The data were chosen because 1) the convenience to obtain the data and 2) updated and precise venue information could be received. For example, the regular search with Foursquare can be used  to explore Manhattan, NY.# New theater location selection in NYC

# %% [markdown]
# ### import libraries

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

# !conda install -c conda-forge geopy --yes
#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ## 1. Download and Explore Dataset

# %%
# !wget -q -O 'newyork_data.json' https://cocl.us/new_york_dataset
print('Data downloaded!')
# Out:
# Data downloaded!

# %%
with open('newyork_data.json') as json_data:
    newyork_data = json.load(json_data)

# %%
 newyork_data # the output too long , don't render this cell

# %%
neighborhoods_data = newyork_data['features']

# %%
neighborhoods_data[0]
# Out:
# {'type': 'Feature',
#  'id': 'nyu_2451_34572.1',
#  'geometry': {'type': 'Point',
#   'coordinates': [-73.84720052054902, 40.89470517661]},
#  'geometry_name': 'geom',
#  'properties': {'name': 'Wakefield',
#   'stacked': 1,
#   'annoline1': 'Wakefield',
#   'annoline2': None,
#   'annoline3': None,
#   'annoangle': 0.0,
#   'borough': 'Bronx',
#   'bbox': [-73.84720052054902,
#    40.89470517661,
#    -73.84720052054902,
#    40.89470517661]}}

# %% [markdown]
# #### Tranform the data into a *pandas* dataframe

# %% [markdown]
# The next task is essentially transforming this data of nested Python dictionaries into a *pandas* dataframe. So let's start by creating an empty dataframe.

# %%
# define the dataframe columns
column_names = ['Borough', 'Neighborhood', 'Latitude', 'Longitude'] 

# instantiate the dataframe
neighborhoods = pd.DataFrame(columns=column_names)

# %% [markdown]
# Take a look at the empty dataframe to confirm that the columns are as intended.

# %%
neighborhoods
# Out:
# Empty DataFrame
# Columns: [Borough, Neighborhood, Latitude, Longitude]
# Index: []

# %% [markdown]
# Then let's loop through the data and fill the dataframe one row at a time.

# %%
for data in neighborhoods_data:
    borough = neighborhood_name = data['properties']['borough'] # which means 'borough' in 'properties' set
    neighborhood_name = data['properties']['name']
        
    neighborhood_latlon = data['geometry']['coordinates']
    neighborhood_lat = neighborhood_latlon[1]
    neighborhood_lon = neighborhood_latlon[0]
    
    neighborhoods = neighborhoods.append({'Borough': borough,
                                          'Neighborhood': neighborhood_name,
                                          'Latitude': neighborhood_lat,
                                          'Longitude': neighborhood_lon}, ignore_index=True)

# %% [markdown]
# For illustration purposes, let's simplify the above map and segment and cluster only the neighborhoods in Manhattan. So let's slice the original dataframe and create a new dataframe of the Manhattan data.

# %%
neighborhoods.head()
# Out:
#   Borough Neighborhood   Latitude  Longitude
# 0   Bronx    Wakefield  40.894705 -73.847201
# 1   Bronx   Co-op City  40.874294 -73.829939
# 2   Bronx  Eastchester  40.887556 -73.827806
# 3   Bronx    Fieldston  40.895437 -73.905643
# 4   Bronx    Riverdale  40.890834 -73.912585

# %% [markdown]
# Let's get the geographical coordinates of Manhattan.

# %%
address = 'New York City'

geolocator = Nominatim(user_agent="ny_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of NYC are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinate of NYC are 40.7127281, -74.0060152.

# %% [markdown]
# Let's visualizat Manhattan the neighborhoods in it.

# %%
# create map of Manhattan using latitude and longitude values
map_manhattan = folium.Map(location=[latitude, longitude], zoom_start=11)

# add markers to map
for lat, lng, label in zip(manhattan_data['Latitude'], manhattan_data['Longitude'], manhattan_data['Neighborhood']):
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_manhattan)  
    
map_manhattan
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Next, we are going to start utilizing the Foursquare API to explore the neighborhoods and segment them.

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %% [markdown]
# #### Let's explore the first neighborhood in our dataframe.

# %% [markdown]
# Get the neighborhood's latitude and longitude values.

# %% [markdown]
# ### Let's search all theaters in New York City, NY

# %%
CLIENT_ID = 'JTBDLVXOVXOMK5C2CIJZVEL4XLRNIIHOYFSAWIVIKA5DXSBV' # your Foursquare ID
CLIENT_SECRET = 'EE2RCSEVPT21M33MIWBNUDLK23VVPGJEDOQ5VF5EUMEKRDLE' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
search_query = 'theater'
radius = 15000
LIMIT=30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
url = 'https://api.foursquare.com/v2/venues/search?client_id=JTBDLVXOVXOMK5C2CIJZVEL4XLRNIIHOYFSAWIVIKA5DXSBV&client_secret=EE2RCSEVPT21M33MIWBNUDLK23VVPGJEDOQ5VF5EUMEKRDLE&ll=40.7127281, -74.0060152&v=20180605&query=theater&radius=15000&limit=30'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
results = requests.get(url).json()
results
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
# Your credentails:
# CLIENT_ID: JTBDLVXOVXOMK5C2CIJZVEL4XLRNIIHOYFSAWIVIKA5DXSBV
# CLIENT_SECRET:EE2RCSEVPT21M33MIWBNUDLK23VVPGJEDOQ5VF5EUMEKRDLE
#                          id                              name  \
# 0  4ea89e6702d5b8174e85e65e  20 Thomas St. (The Flea Theater)
# 1  4bf470e194af2d7f0a9e3a72         Schaeberle Studio Theater
# 2  4be070a3652b0f47c7727211                       Theater Bar
# 3  4b032755f964a5200f4d22e3               iHeartRadio Theater
# 4  4c3d0ec67c1ee21e017e8d71              Royal Theater Cinema
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d137941735', 'name': 'T...  v-1594642768    False
# 1  [{'id': '4bf58dd8d48988d1ac941735', 'name': 'C...  v-1594642768    False
# 2  [{'id': '4bf58dd8d48988d11e941735', 'name': 'C...  v-1594642768    False
# 3  [{'id': '4bf58dd8d48988d1e5931735', 'name': 'M...  v-1594642768    False
# 4  [{'id': '4bf58dd8d48988d17f941735', 'name': 'M...  v-1594642768    False
#
#             location.address  location.lat  location.lng  \
# 0               20 Thomas St     40.716161    -74.005826
# 1                41 Park Row     40.711158    -74.005322
# 2            114 Franklin St     40.718688    -74.006300
# 3  32 Avenue of the Americas     40.720312    -74.005150
# 4                 63 Wall St     40.705627    -74.008774
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 40.71616108888684...                382
# 1  [{'label': 'display', 'lat': 40.71115829255644...                184
# 2  [{'label': 'display', 'lat': 40.71868815941004...                663
# 3  [{'label': 'display', 'lat': 40.72031234030413...                847
# 4  [{'label': 'display', 'lat': 40.70562744140625...                824
#
#   location.postalCode location.cc location.city location.state  \
# 0               10007          US      New York             NY
# 1               10038          US      New York             NY
# 2               10013          US      New York             NY
# 3               10013          US      New York             NY
# 4               10005          US      New York             NY
#
#   location.country                          location.formattedAddress  \
# 0    United States  [20 Thomas St, New York, NY 10007, United States]
# 1    United States  [41 Park Row (at Pace University), New York, N...
# 2    United States  [114 Franklin St (btw W Bway & Church St), New...
# 3    United States  [32 Avenue of the Americas (at Walker St), New...
# 4    United States  [63 Wall St (Pearl St), New York, NY 10005, Un...
#
#      location.crossStreet venuePage.id location.neighborhood
# 0                     NaN          NaN                   NaN
# 1      at Pace University          NaN                   NaN
# 2  btw W Bway & Church St          NaN                   NaN
# 3            at Walker St     32694113                   NaN
# 4                Pearl St          NaN                   NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                     name             categories  \
# 0       20 Thomas St. (The Flea Theater)                Theater
# 1              Schaeberle Studio Theater        College Theater
# 2                            Theater Bar           Cocktail Bar
# 3                    iHeartRadio Theater            Music Venue
# 4                   Royal Theater Cinema          Movie Theater
# 5               Theater for the New City                Theater
# 6                       Theater District           Neighborhood
# 7                Peter Jay Sharp Theater                Theater
# 8            LES* Drive-In Movie Theater          Movie Theater
# 9                     The Public Theater                Theater
# 10                          Hulu Theater            Music Venue
# 11                        Nevada Theater              Multiplex
# 12                     St Venice Theater             Strip Club
# 13                     Delacorte Theater                Theater
# 14                      Connelly Theater          Indie Theater
# 15        iPic Theaters at Fulton Market          Movie Theater
# 16                       Pioneer Theater              Multiplex
# 17      Russian American Musical Theater           Concert Hall
# 18        Public Theater Conference Room        Conference Room
# 19                     Theater 219 (VPR)                Theater
# 20                   Robert Moss Theater          Indie Theater
# 21                         Galli Theater                Theater
# 22                     Time Inc. Theater           Amphitheater
# 23  IRT (Interborough Repertory Theater)          Indie Theater
# 24                        Kumble Theater  Performing Arts Venue
# 25                        Kraine Theater                Theater
# 26   Helen Mills Event Space and Theater            Event Space
# 27                   See Forever Theater                Theater
# 28                         accss theater                Theater
# 29       Collective: Unconscious Theater                Theater
#
#                       address        lat        lng  \
# 0                20 Thomas St  40.716161 -74.005826
# 1                 41 Park Row  40.711158 -74.005322
# 2             114 Franklin St  40.718688 -74.006300
# 3   32 Avenue of the Americas  40.720312 -74.005150
# 4                  63 Wall St  40.705627 -74.008774
# 5                 155 1st Ave  40.728612 -73.984681
# 6                         NaN  40.758912 -73.985715
# 7                  235 Bowery  40.722347 -73.992844
# 8                   88 Ludlow  40.718087 -73.989058
# 9            425 Lafayette St  40.729169 -73.992070
# 10                 4 Penn Plz  40.750923 -73.994079
# 11             Waterside Park  40.714354 -74.005972
# 12                        NaN  40.713491 -74.009126
# 13               Central Park  40.780265 -73.968780
# 14               220 E 4th St  40.723501 -73.983488
# 15               11 Fulton St  40.706752 -74.003418
# 16               155 E 3rd St  40.723572 -73.984833
# 17              100 Church St  40.713067 -74.009453
# 18           425 Lafayette St  40.729162 -73.991941
# 19               219 Court St  40.686538 -73.993599
# 20           440 Lafayette St  40.729392 -73.991884
# 21                89 South St  40.708816 -74.004786
# 22        225 Liberty St Fl 4  40.711628 -74.015080
# 23         154 Christopher St  40.732211 -74.008084
# 24     Long Island University  40.691261 -73.981225
# 25                85 E 4th St  40.726507 -73.989838
# 26         137-139 W 26th St.  40.745462 -73.992877
# 27                        NaN  40.712983 -74.013107
# 28                        NaN  40.718046 -74.003078
# 29              279 Church St  40.718578 -74.004692
#
#                                        labeledLatLngs  distance postalCode  \
# 0   [{'label': 'display', 'lat': 40.71616108888684...       382      10007
# 1   [{'label': 'display', 'lat': 40.71115829255644...       184      10038
# 2   [{'label': 'display', 'lat': 40.71868815941004...       663      10013
# 3   [{'label': 'display', 'lat': 40.72031234030413...       847      10013
# 4   [{'label': 'display', 'lat': 40.70562744140625...       824      10005
# 5   [{'label': 'display', 'lat': 40.72861171634928...      2523      10003
# 6                                                 NaN      5418      10036
# 7   [{'label': 'display', 'lat': 40.72234725952148...      1543      10002
# 8   [{'label': 'display', 'lat': 40.71808685300118...      1550      10002
# 9   [{'label': 'display', 'lat': 40.72916880904384...      2175      10003
# 10  [{'label': 'display', 'lat': 40.75092318110860...      4369      10121
# 11  [{'label': 'display', 'lat': 40.714354004484, ...       181      10011
# 12  [{'label': 'display', 'lat': 40.713491, 'lng':...       275        NaN
# 13  [{'label': 'display', 'lat': 40.78026521337381...      8147      10028
# 14  [{'label': 'display', 'lat': 40.72350091305057...      2247      10009
# 15  [{'label': 'display', 'lat': 40.7067518, 'lng'...       700      10038
# 16  [{'label': 'display', 'lat': 40.72357177734375...      2156      10009
# 17  [{'label': 'display', 'lat': 40.713067, 'lng':...       292      10007
# 18  [{'label': 'display', 'lat': 40.729162, 'lng':...      2180      10003
# 19  [{'label': 'display', 'lat': 40.686538, 'lng':...      3098      11201
# 20  [{'label': 'display', 'lat': 40.72939219411654...      2205      10003
# 21  [{'label': 'display', 'lat': 40.70881608089884...       447      10038
# 22  [{'label': 'display', 'lat': 40.711628, 'lng':...       774      10281
# 23  [{'label': 'display', 'lat': 40.73221067804905...      2175      10014
# 24  [{'label': 'display', 'lat': 40.69126110371390...      3176        NaN
# 25  [{'label': 'display', 'lat': 40.72650690868777...      2053      10003
# 26  [{'label': 'display', 'lat': 40.74546218864443...      3808      10001
# 27  [{'label': 'display', 'lat': 40.712983, 'lng':...       599      10007
# 28  [{'label': 'display', 'lat': 40.718046, 'lng':...       641        NaN
# 29  [{'label': 'display', 'lat': 40.71857833862305...       660      10013
#
#     cc      city state        country  \
# 0   US  New York    NY  United States
# 1   US  New York    NY  United States
# 2   US  New York    NY  United States
# 3   US  New York    NY  United States
# 4   US  New York    NY  United States
# 5   US  New York    NY  United States
# 6   US  New York    NY  United States
# 7   US  New York    NY  United States
# 8   US  New York    NY  United States
# 9   US  New York    NY  United States
# 10  US  New York    NY  United States
# 11  US  New York    NY  United States
# 12  US  New York    NY  United States
# 13  US  New York    NY  United States
# 14  US  New York    NY  United States
# 15  US  New York    NY  United States
# 16  US  New York    NY  United States
# 17  US  New York    NY  United States
# 18  US  New York    NY  United States
# 19  US  Brooklyn    NY  United States
# 20  US  New York    NY  United States
# 21  US  New York    NY  United States
# 22  US  New York    NY  United States
# 23  US  New York    NY  United States
# 24  US  Brooklyn    NY  United States
# 25  US  New York    NY  United States
# 26  US  New York    NY  United States
# 27  US  New York    NY  United States
# 28  US  New York    NY  United States
# 29  US  New York    NY  United States
#
#                                      formattedAddress  \
# 0   [20 Thomas St, New York, NY 10007, United States]
# 1   [41 Park Row (at Pace University), New York, N...
# 2   [114 Franklin St (btw W Bway & Church St), New...
# 3   [32 Avenue of the Americas (at Walker St), New...
# 4   [63 Wall St (Pearl St), New York, NY 10005, Un...
# 5   [155 1st Ave (Between 9th and 10th Streets), N...
# 6                 [New York, NY 10036, United States]
# 7     [235 Bowery, New York, NY 10002, United States]
# 8   [88 Ludlow (Ludlow and Broom), New York, NY 10...
# 9   [425 Lafayette St (btwn Astor Pl & E 4th St), ...
# 10    [4 Penn Plz, New York, NY 10121, United States]
# 11  [Waterside Park (37 West 17th Street), New Yor...
# 12                      [New York, NY, United States]
# 13  [Central Park (at 79th St), New York, NY 10028...
# 14  [220 E 4th St (btwn Avenue A & B), New York, N...
# 15  [11 Fulton St (at South St), New York, NY 1003...
# 16  [155 E 3rd St (Ave A), New York, NY 10009, Uni...
# 17  [100 Church St, New York, NY 10007, United Sta...
# 18  [425 Lafayette St, New York, NY 10003, United ...
# 19  [219 Court St, Brooklyn, NY 11201, United States]
# 20  [440 Lafayette St (Astor Place), New York, NY ...
# 21   [89 South St, New York, NY 10038, United States]
# 22  [225 Liberty St Fl 4, New York, NY 10281, Unit...
# 23  [154 Christopher St (btw Greenwich and Washing...
# 24  [Long Island University, Brooklyn, NY, United ...
# 25  [85 E 4th St (2nd Ave and Bowery), New York, N...
# 26  [137-139 W 26th St. (btwn 6th & 7th Ave.), New...
# 27                [New York, NY 10007, United States]
# 28                      [New York, NY, United States]
# 29  [279 Church St, New York, NY 10013, United Sta...
#
#                      crossStreet  neighborhood                        id
# 0                            NaN           NaN  4ea89e6702d5b8174e85e65e
# 1             at Pace University           NaN  4bf470e194af2d7f0a9e3a72
# 2         btw W Bway & Church St           NaN  4be070a3652b0f47c7727211
# 3                   at Walker St           NaN  4b032755f964a5200f4d22e3
# 4                       Pearl St           NaN  4c3d0ec67c1ee21e017e8d71
# 5   Between 9th and 10th Streets           NaN  431f7f00f964a5208c271fe3
# 6                            NaN           NaN  4edab7350e011b46eed5778a
# 7                            NaN           NaN  5d30f415d6746d0008b3918b
# 8               Ludlow and Broom           NaN  51be383f501974b71a897e60
# 9       btwn Astor Pl & E 4th St           NaN  4a07986bf964a52087731fe3
# 10                           NaN           NaN  4e8c7d54e5fa774802eb9515
# 11           37 West 17th Street           NaN  4cdd16f2cbed60fc34634f9f
# 12                           NaN           NaN  56da7c2dcd10611e1928174a
# 13                    at 79th St  Central Park  4a314b58f964a520ae991fe3
# 14             btwn Avenue A & B           NaN  4a6101daf964a520abc11fe3
# 15                   at South St           NaN  57218ba5498eb662eaa1e121
# 16                         Ave A           NaN  4339dd00f964a52033281fe3
# 17                           NaN           NaN  4f32d01019836c91c7fd74ef
# 18                           NaN           NaN  4c9ce9ef54c8a1cd0bb77e4b
# 19                           NaN           NaN  4dc57cf6fa76d685cde1c729
# 20                   Astor Place           NaN  4a8b3c20f964a520e10b20e3
# 21                           NaN           NaN  4e32d87981dc7846377caf22
# 22                           NaN           NaN  56e9d454498ecbb9758bd5ed
# 23  btw Greenwich and Washington           NaN  4b3fed4df964a5204bb225e3
# 24                           NaN           NaN  4bba4d7398c7ef3b9fef3202
# 25            2nd Ave and Bowery           NaN  44f28948f964a5200c381fe3
# 26           btwn 6th & 7th Ave.           NaN  4bbfc22cb492d13ae143a360
# 27                           NaN           NaN  5a4cf9df66fc657e367a49c2
# 28                           NaN           NaN  54caa9d1498e1f08d768a8a6
# 29                           NaN           NaN  4276bf00f964a52087211fe3

# %%
dataframe_filtered.name
# Out:
# 0         20 Thomas St. (The Flea Theater)
# 1                Schaeberle Studio Theater
# 2                              Theater Bar
# 3                      iHeartRadio Theater
# 4                     Royal Theater Cinema
# 5                 Theater for the New City
# 6                         Theater District
# 7                  Peter Jay Sharp Theater
# 8              LES* Drive-In Movie Theater
# 9                       The Public Theater
# 10                            Hulu Theater
# 11                          Nevada Theater
# 12                       St Venice Theater
# 13                       Delacorte Theater
# 14                        Connelly Theater
# 15          iPic Theaters at Fulton Market
# 16                         Pioneer Theater
# 17        Russian American Musical Theater
# 18          Public Theater Conference Room
# 19                       Theater 219 (VPR)
# 20                     Robert Moss Theater
# 21                           Galli Theater
# 22                       Time Inc. Theater
# 23    IRT (Interborough Repertory Theater)
# 24                          Kumble Theater
# 25                          Kraine Theater
# 26     Helen Mills Event Space and Theater
# 27                     See Forever Theater
# 28                           accss theater
# 29         Collective: Unconscious Theater
# Name: name, dtype: object

# %% [markdown]
# ### Visualize theater places in Manhattan

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) 

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Based on the map, the planned theater should be placed near NYC City Hall because this area has the most theaters located and a highly possible place people would like to visit to enjoy the performing arts compared to other locations.
